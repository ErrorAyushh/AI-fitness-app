# %%
pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (0.10.21)
# Requirement already satisfied: absl-py in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (0.7.0)
# Requirement already satisfied: jaxlib in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (0.7.0)
# Requirement already satisfied: matplotlib in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (3.10.5)
# Requirement already satisfied: numpy<2 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from jax->mediapipe) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lib9\anaconda3\envs\mp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import math

class poseDetector() :
    
    def __init__(self, mode=False, complexity=1, smooth_landmarks=True,
                 enable_segmentation=False, smooth_segmentation=True,
                 detectionCon=0.5, trackCon=0.5):
        
        self.mode = mode 
        self.complexity = complexity
        self.smooth_landmarks = smooth_landmarks
        self.enable_segmentation = enable_segmentation
        self.smooth_segmentation = smooth_segmentation
        self.detectionCon = detectionCon
        self.trackCon = trackCon
        
        self.mpDraw = mp.solutions.drawing_utils
        self.mpPose = mp.solutions.pose
        self.pose = self.mpPose.Pose(self.mode, self.complexity, self.smooth_landmarks,
                                     self.enable_segmentation, self.smooth_segmentation,
                                     self.detectionCon, self.trackCon)
        
        
    def findPose (self, img, draw=True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.pose.process(imgRGB)
        
        if self.results.pose_landmarks:
            if draw:
                self.mpDraw.draw_landmarks(img,self.results.pose_landmarks,
                                           self.mpPose.POSE_CONNECTIONS)
                
        return img
    
    def findPosition(self, img, draw=True):
        self.lmList = []
        if self.results.pose_landmarks:
            for id, lm in enumerate(self.results.pose_landmarks.landmark):
                #finding height, width of the image printed
                h, w, c = img.shape
                #Determining the pixels of the landmarks
                cx, cy = int(lm.x * w), int(lm.y * h)
                self.lmList.append([id, cx, cy])
                if draw:
                    cv2.circle(img, (cx, cy), 5, (255,0,0), cv2.FILLED)
        return self.lmList
        
    def findAngle(self, img, p1, p2, p3, draw=True):   
        #Get the landmarks
        x1, y1 = self.lmList[p1][1:]
        x2, y2 = self.lmList[p2][1:]
        x3, y3 = self.lmList[p3][1:]
        
        
        angle = math.degrees(math.atan2(y3-y2, x3-x2) - 
                             math.atan2(y1-y2, x1-x2))
        if angle < 0:
            angle += 360
            if angle > 180:
                angle = 360 - angle
        elif angle > 180:
            angle = 360 - angle
        # print(angle)
        
        #Draw
        if draw:
            cv2.line(img, (x1, y1), (x2, y2), (255,255,255), 3)
            cv2.line(img, (x3, y3), (x2, y2), (255,255,255), 3)

            
            cv2.circle(img, (x1, y1), 5, (0,0,255), cv2.FILLED)
            cv2.circle(img, (x1, y1), 15, (0,0,255), 2)
            cv2.circle(img, (x2, y2), 5, (0,0,255), cv2.FILLED)
            cv2.circle(img, (x2, y2), 15, (0,0,255), 2)
            cv2.circle(img, (x3, y3), 5, (0,0,255), cv2.FILLED)
            cv2.circle(img, (x3, y3), 15, (0,0,255), 2)
            
            cv2.putText(img, str(int(angle)), (x2-50, y2+50), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0,0,255), 2)
        return angle
        

def main():
    detector = poseDetector()
    cap = cv2.VideoCapture(0)
    while cap.isOpened():
        ret, img = cap.read() #ret is just the return variable, not much in there that we will use. 
        if ret:    
            img = detector.findPose(img)
            cv2.imshow('Pose Detection', img)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
    
if __name__ == "__main__":
    main()

# %%
# !python --version
# Out:
# Python 3.13.5
